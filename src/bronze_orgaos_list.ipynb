# %%
df = spark.read.json("/Volumes/raw/compras_governamentais/compras_governamentais_raw/orgaos_list/")
(df.distinct()
 .coalesce(1)
 .write
 .format("delta")
 .mode("overwrite")
 .saveAsTable("bronze.compras_governamentais.orgaos_list"))

# %%
# %sql

SELECT *
FROM bronze.compras_governamentais.orgaos_list
